# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\priya\\internship\\advertising.csv")

# %%
df.shape
# Out:
# (200, 4)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(df, x_vars=['TV', 'Radio', 'Newspaper'], y_vars=['Sales'], kind='scatter')
plt.show()
# Out:
# C:\Users\shwet\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['TV'].plot.hist(bins=10, color='Yellow', xlabel= 'TV')
# Out:
# <Axes: xlabel='TV', ylabel='Frequency'>

# %%
df['Radio'].plot.hist(bins=10, color='Red', xlabel='Radio')
# Out:
# <Axes: xlabel='Radio', ylabel='Frequency'>

# %%
df['Newspaper'].plot.hist(bins=10, color='Green', xlabel='Newspaper')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Frequency'>

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(df[['TV', 'Radio', 'Newspaper']], df[['Sales']], test_size=0.3)

# %%
print(X_train)
# Out:
#         TV  Radio  Newspaper
# 133  219.8   33.5       45.1
# 145  140.3    1.9        9.0
# 144   96.2   14.8       38.9
# 119   19.4   16.0       22.3
# 40   202.5   22.3       31.6
# ..     ...    ...        ...
# 16    67.8   36.6      114.0
# 75    16.9   43.7       89.4
# 149   44.7   25.8       20.6
# 39   228.0   37.7       32.0
# 128  220.3   49.0        3.2
#
# [140 rows x 3 columns]

# %%
print(y_train)
# Out:
#      Sales
# 133   19.6
# 145   10.3
# 144   12.3
# 119    6.6
# 40    16.6
# ..     ...
# 16    12.5
# 75     8.7
# 149   10.1
# 39    21.5
# 128   24.7
#
# [140 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
result=model.predict(X_test)
print(result)
# Out:
# [[18.74116209]
#  [20.74516456]
#  [10.79405773]
#  [ 7.61866126]
#  [11.87357769]
#  [15.07194266]
#  [ 8.30197443]
#  [20.65329052]
#  [13.76847974]
#  [ 9.42168928]
#  [15.85861412]
#  [16.53618515]
#  [18.08655956]
#  [11.47162877]
#  [12.36165852]
#  [19.728808  ]
#  [18.58612465]
#  [ 7.36026553]
#  [12.05732576]
#  [20.49825308]
#  [21.87062153]
#  [19.1201425 ]
#  [23.28892701]
#  [13.81441676]
#  [21.43996198]
#  [21.95101132]
#  [11.93674109]
#  [17.35156725]
#  [14.98006862]
#  [23.02478914]
#  [13.17129848]
#  [19.41299099]
#  [19.36705398]
#  [ 8.40533272]
#  [19.8321663 ]
#  [14.08429674]
#  [ 7.94596253]
#  [22.0945645 ]
#  [15.46814945]
#  [20.04462501]
#  [17.65015788]
#  [22.98459425]
#  [20.33173138]
#  [16.44431112]
#  [15.32459627]
#  [11.25342792]
#  [10.28875052]
#  [20.63606414]
#  [20.5441901 ]
#  [12.44779043]
#  [ 7.83686211]
#  [20.6073535 ]
#  [19.63693396]
#  [11.25342792]
#  [19.40724887]
#  [18.21288636]
#  [11.35678622]
#  [17.03000811]
# ...

# %%
print(X_test)
# Out:
#         TV  Radio  Newspaper
# 121   18.8   21.7       50.4
# 112  175.7   15.4        2.4
# 194  149.7   35.6        6.0
# 82    75.3   20.3       32.5
# 12    23.8   35.1       65.9
# 11   214.7   24.0        4.0
# 178  276.7    2.3       23.7
# 42   293.6   27.7        1.8
# 132    8.4   27.2        2.1
# 21   237.4    5.1       23.5
# 23   228.3   16.9       26.2
# 163  163.5   36.8        7.4
# 198  283.6   42.0       66.2
# 189   18.7   12.1       23.4
# 46    89.7    9.9       35.7
# 30   292.9   28.3       43.2
# 136   25.6   39.0        9.3
# 20   218.4   27.7       53.4
# 4    180.8   10.8       58.4
# 8      8.6    2.1        1.0
# 177  170.2    7.8       35.2
# 176  248.4   30.2       20.3
# 85   193.2   18.4       65.7
# 140   73.4   17.0       12.9
# 79   116.0    7.7       23.1
# 179  165.6   10.0       17.6
# 130    0.7   39.6        8.7
# 86    76.3   27.5       16.0
# 185  205.0   45.1       19.6
# 147  243.2   49.0       44.3
# 68   237.4   27.5       11.0
# ...

# %%
print(y_test)
# Out:
#      Sales
# 121    7.0
# 112   17.1
# 194   17.3
# 82    11.3
# 12     9.2
# 11    17.4
# 178   16.8
# 42    20.7
# 132    5.7
# 21    17.5
# 23    20.5
# 163   18.0
# 198   25.5
# 189    6.7
# 46    10.6
# 30    21.4
# 136    9.5
# 20    18.0
# 4     17.9
# 8      4.8
# 177   16.7
# 176   20.2
# 85    20.2
# 140   10.9
# 79    11.0
# 179   17.6
# 130    1.6
# 86    12.0
# 185   22.6
# 147   25.4
# 68    18.9
# 108    5.3
# 37    14.7
# 87    16.0
# 120   15.5
# 32    13.2
# 31    11.9
# 17    24.4
# 36    25.4
# 167   17.2
# 166    8.0
# 124   19.7
# 134   10.8
# 89    16.7
# 141   19.2
# 24     9.7
# 72     8.8
# 2     12.0
# 183   26.2
# 103   19.7
# 106    7.2
# 190   10.8
# 84    21.7
# 59    18.4
# 70    18.3
# 5      7.2
# 6     11.8
# 10    12.6
# 175   27.0
# 92    19.4

# %%
model.coef_
# Out:
# array([[ 0.05269507,  0.11698081, -0.00817353]])

# %%
model.intercept_
# Out:
# array([4.88539768])

# %%
plt.plot(result)
